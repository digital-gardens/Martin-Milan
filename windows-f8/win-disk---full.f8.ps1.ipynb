# %% [markdown]
# 2505 new way of navigation in vscode,  click on the file name in the 3rd top line of the editor,  files with the same folder and similar name prefix are grouped together
# C:\Users\marti\OneDrive\windows-f8\win-disk*

# %%
cmd /c dir c:\ /al

# file:///C:\Users\marti\OneDrive\2400-WIKI\250407.md  symlink junction
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 2480-D21D
#
#  Directory of c:\
#
# 05/30/2020  23:53    <JUNCTION>     Documents and Settings [C:\Users]
# 05/10/2022  22:50    <SYMLINKD>     gib [C:\pf\Git\usr\bin]
# 02/20/2021  21:23    <SYMLINKD>     pf [C:\Program Files]
# 02/20/2021  21:24    <SYMLINKD>     pf86 [C:\Program Files (x86)]
# 05/10/2022  23:46    <SYMLINKD>     spu [C:\Users\marti\OneDrive\AAAA-spust-linked]
# 02/20/2021  21:35    <SYMLINKD>     u [C:\Users\marti]
#                0 File(s)              0 bytes
#                6 Dir(s)  16,847,925,248 bytes free

# %%
#wsl --help
wsl --list --verbose --all
# tc find files advanced file size > 1 gib

# %%
dir "C:\Users\marti\AppData\Local\Packages\CanonicalGroupLimited.Ubuntu22.04LTS_79rhkp1fndgsc\LocalState\ext4.vhdx"
dir "C:\Users\marti\AppData\Local\Packages\CanonicalGroupLimited*\LocalState\ext4.vhdx"
dir "C:\Users\marti\AppData\Local\Packages\CanonicalGroupLimited*\*\*.vhdx"
# Out:
#     Directory:
# C:\Users\marti\AppData\Local\Packages\CanonicalGroupLimited.Ubuntu22.04LTS_79rhkp1fndgsc\LocalState
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a---            4/8/2025 12:11 AM     7873757184 ext4.vhdx
# -a---            4/8/2025 12:11 AM     7873757184 ext4.vhdx
# -a---            4/8/2025 12:11 AM     7873757184 ext4.vhdx

# %%
wsl --list --verbose --all
# wsl delete podman-machine-default
wsl --unregister podman-machine-default
wsl --list --verbose --all
# Out:
#   NAME                      STATE           VERSION
#
#   Ubuntu-22.04              Running         2
#
#   podman-machine-default    Running         2
#
#
# The operation completed successfully.
#
#
#   NAME            STATE           VERSION
#
#   Ubuntu-22.04    Running         2

# %%
# explorer this pc
explorer.exe  # f4 this pc
wsl --list --verbose --all
# Out:
#   NAME                      STATE           VERSION
#
#   Ubuntu-22.04              Running         2
#
#   podman-machine-default    Running         2

# %%
# close TC ... no help
# explorer  this pc / podman-machine-default (\\wsl.localhost) (P:) #  disconnect ... no help
# close the explorer window ... no help

#  podman-machine-default    Running         2   ?!
wsl --shutdown --all --verbose
wsl --list --verbose --all
dir c:\Users\marti\.local\share\containers\podman\machine\wsl\wsldist\podman-machine-default\
# Out:
#   NAME            STATE           VERSION
#
#   Ubuntu-22.04    Stopped         2
#
#
# Get-ChildItem:
# Line |
#    8 |  dir c:\Users\marti\.local\share\containers\podman\machine\wsl\wsldist …
#      |  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#      | Cannot find path 'C:\Users\marti\.local\share\containers\podman\machine\wsl\wsldist\podman-machine-default\' because it does not exist.
# Command failed: SubmitCode: # close TC ... no help ...

# %%
mkdir D:\umarti\246-du64

# %%
diskusage.exe /a   /h   /t:10
diskusage.exe   /h   /t:10   C:\Users\marti\OneDrive
# Out:
# The DiskUsage utility requires that you have administrative privileges.
# The DiskUsage utility requires that you have administrative privileges.

# %%
# spust hned, trva dlho

# %%
dotnet.exe  --info
# Out:
# .NET SDK:
#  Version:           8.0.204
#  Commit:            c338c7548c
#  Workload version:  8.0.200-manifests.7d36c14f
#
# Runtime Environment:
#  OS Name:     Windows
#  OS Version:  10.0.22631
#  OS Platform: Windows
#  RID:         win-x64
#  Base Path:   C:\Program Files\dotnet\sdk\8.0.204\
#
# .NET workloads installed:
# There are no installed workloads to display.
#
# Host:
#   Version:      8.0.4
#   Architecture: x64
#   Commit:       2d7eea2529
#
# .NET SDKs installed:
#   6.0.109 [C:\Program Files\dotnet\sdk]
#   8.0.204 [C:\Program Files\dotnet\sdk]
#
# .NET runtimes installed:
#   Microsoft.AspNetCore.App 6.0.9 [C:\Program Files\dotnet\shared\Microsoft.AspNetCore.App]
#   Microsoft.AspNetCore.App 7.0.18 [C:\Program Files\dotnet\shared\Microsoft.AspNetCore.App]
#   Microsoft.AspNetCore.App 8.0.4 [C:\Program Files\dotnet\shared\Microsoft.AspNetCore.App]
#   Microsoft.NETCore.App 3.1.29 [C:\Program Files\dotnet\shared\Microsoft.NETCore.App]
# ...

# %%
cd D:\umarti
cd 'D:\A,SMAZAT-V-NOUZI'
cd 'D:\'    #  50s
cd 'c:\'    #  7  min 3  junctio?
cmd /c dir /b /s  *du-m*
# Out:
# C:\u\du-m-mar.sort
# C:\u\bOLDOLD---------OLD\du-m - Copy.txt
# C:\u\bOLDOLD---------OLD\d-conda-old\du-m - Copy (2).txt
# C:\u\bOLDOLD---------OLD\d-conda-old\du-m - Copy.txt
# C:\u\bOLDOLD---------OLD\d-conda-old\du-m.txt
# C:\u\busytex\dist\ALMA246g\var\www\du-m.txt
# C:\u\OneDrive\alma-233c\var\www\du-m.txt
# C:\u\OneDrive\conda-dotfiles\d-conda\du-m-conda.sort
# C:\u\OneDrive\conda-dotfiles\old\du-m - Copy (2).txt
# C:\u\OneDrive\conda-dotfiles\old\du-m.txt
# C:\Users\marti\du-m-mar.sort
# C:\Users\marti\bOLDOLD---------OLD\du-m - Copy.txt
# C:\Users\marti\bOLDOLD---------OLD\d-conda-old\du-m - Copy (2).txt
# C:\Users\marti\bOLDOLD---------OLD\d-conda-old\du-m - Copy.txt
# C:\Users\marti\bOLDOLD---------OLD\d-conda-old\du-m.txt
# C:\Users\marti\busytex\dist\ALMA246g\var\www\du-m.txt
# C:\Users\marti\OneDrive\alma-233c\var\www\du-m.txt
# C:\Users\marti\OneDrive\conda-dotfiles\d-conda\du-m-conda.sort
# C:\Users\marti\OneDrive\conda-dotfiles\old\du-m - Copy (2).txt
# ...

# %%
C:\u\du-m-mar.sort
C:\u\bOLDOLD---------OLD\du-m - Copy.txt
C:\u\bOLDOLD---------OLD\d-conda-old\du-m - Copy (2).txt
C:\u\bOLDOLD---------OLD\d-conda-old\du-m - Copy.txt
C:\u\bOLDOLD---------OLD\d-conda-old\du-m.txt

cmd
dir C:\u\busytex\dist\ALMA246g\var\www\du-m.txt
dir C:\u\busytex\dist\ALMA246g
dir C:\u\busytex\dist\
dir C:\u\busytex\dist
dir C:\u\busytex\
# downloads
exit
bash
#ls -latr 'C:\u\busytex\dist/'
cmd /c dir d:\umarti\dow*

C:\u\OneDrive\alma-233c\var\www\du-m.txt
C:\u\OneDrive\conda-dotfiles\d-conda\du-m-conda.sort
C:\u\OneDrive\conda-dotfiles\old\du-m - Copy (2).txt
C:\u\OneDrive\conda-dotfiles\old\du-m.txt

C:\Users\marti\du-m-mar.sort
C:\Users\marti\bOLDOLD---------OLD\du-m - Copy.txt
C:\Users\marti\bOLDOLD---------OLD\d-conda-old\du-m - Copy (2).txt
C:\Users\marti\bOLDOLD---------OLD\d-conda-old\du-m - Copy.txt
C:\Users\marti\bOLDOLD---------OLD\d-conda-old\du-m.txt
C:\Users\marti\busytex\dist\ALMA246g\var\www\du-m.txt
C:\Users\marti\OneDrive\alma-233c\var\www\du-m.txt
C:\Users\marti\OneDrive\conda-dotfiles\d-conda\du-m-conda.sort
C:\Users\marti\OneDrive\conda-dotfiles\old\du-m - Copy (2).txt
C:\Users\marti\OneDrive\conda-dotfiles\old\du-m.txt

# %%
# 2505
#cmd /c dir  C:\Users\marti\OneDrive   /b /ad /s    >C:\Users\marti\8
cmd /c dir  C:\Users\marti\OneDrive   /b  /s    >C:\Users\marti\82

# %%
cmd /c dir  C:\Users\marti\OneDrive   /b >C:\Users\marti\80
#cmd /c dir  C:\Users\marti\OneDrive   /b  /s    >C:\Users\marti\82

# %%
cmd /c dir     /b >C:\Users\marti\80  c:\Windows\WinSxS\
#cmd /c dir  C:\Users\marti\OneDrive   /b  /s    >C:\Users\marti\82

# %%
& 'C:\Program Files\totalcmd\TOTALCMD64.EXE'  c:\Windows\WinSxS\
# 9s
