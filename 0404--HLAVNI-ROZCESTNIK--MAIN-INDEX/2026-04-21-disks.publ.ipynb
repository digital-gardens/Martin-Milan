# %% [markdown]
# ---
#
# songs:
#
# emojis:
#
# blissymbols:   _💚_
#
# tags:
#
# title:
#
# parents:
#   - 2028-new-pc
#   - 260301-disks.publ.md
#
# description:
#   - enlarge the C drive
#   - move the D drive to a new disk
#
#   - buy a new disk for the D drive
#
#   - enhance possibilities for recovery and backup
#
# concurrent:
#   - 0b-vyhýbat-se-nemocnici
#
# ---
