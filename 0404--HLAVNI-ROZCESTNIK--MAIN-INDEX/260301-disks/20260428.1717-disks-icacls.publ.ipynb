# %% [markdown]
# # protect NTFS partition from write access by Everyone, Users, Authenticated Users, etc.
#
# i have created a ntfs partition
#
#
# // Remove "Allow" Rules Instead of Using "Deny" Rules: It is a common mistake to try and secure a drive by running icacls G:\ /deny Everyone:(W). Do not do this. Explicit "Deny" rules take precedence over "Allow" rules in Windows. If you deny "Everyone" or "Users", you will likely lock out your own Administrator account (since Admins are also members of the Everyone/Users groups). Always secure a drive by removing the overly permissive "Allow" groups, as shown in the commands above.

# %%
icacls c:\
icacls.exe d:\
icacls.exe e:\
icacls.exe f:\
# Out:
# c:\ S-1-15-3-65536-1888954469-739942743-1668119174-2468466756-4239452838-1296943325-355587736-700089176:(S,RD,X,RA)
#     BUILTIN\Administrators:(OI)(CI)(F)
#     NT AUTHORITY\SYSTEM:(OI)(CI)(F)
#     BUILTIN\Users:(OI)(CI)(RX)
#     NT AUTHORITY\Authenticated Users:(OI)(CI)(IO)(RX)
#     Mandatory Label\High Mandatory Level:(OI)(NP)(IO)(NW)
#
# Successfully processed 1 files; Failed processing 0 files
# d:\ NT AUTHORITY\Authenticated Users:(OI)(CI)(IO)(RX)
#     NT AUTHORITY\SYSTEM:(OI)(CI)(F)
#     BUILTIN\Administrators:(OI)(CI)(F)
#     BUILTIN\Users:(OI)(CI)(RX)
#
# Successfully processed 1 files; Failed processing 0 files
# e:\ Everyone:(OI)(CI)(RX)
#     CREATOR OWNER:(OI)(CI)(IO)(F)
#     NT AUTHORITY\SYSTEM:(OI)(CI)(F)
#     MB-PC\milan_rxtipwr:(OI)(CI)(F)
#     BUILTIN\Administrators:(OI)(CI)(F)
#
# Successfully processed 1 files; Failed processing 0 files
# f:\ BUILTIN\Administrators:(F)
#     BUILTIN\Administrators:(OI)(CI)(IO)(F)
#     NT AUTHORITY\SYSTEM:(F)
# ...

# %%
icacls g:\
# interesting output ... i feel..maybe, yesterday i have seen Everyone:(OI)(CI)(F) in the output before, but now it is not there anymore,..... which is good, because i want to remove write access for everyone, users, authenticated users, etc.
# who fixed it? who removed the item Everyone ? maybe Windows?
# Out:
# g:\ BUILTIN\Administrators:(F)
#     BUILTIN\Administrators:(OI)(CI)(IO)(F)
#     NT AUTHORITY\SYSTEM:(F)
#     NT AUTHORITY\SYSTEM:(OI)(CI)(IO)(F)
#     NT AUTHORITY\Authenticated Users:(M)
#     NT AUTHORITY\Authenticated Users:(OI)(CI)(IO)(M)
#     BUILTIN\Users:(RX)
#     BUILTIN\Users:(OI)(CI)(IO)(GR,GE)
#
# Successfully processed 1 files; Failed processing 0 files

# %%
#    CREATOR OWNER:(OI)(CI)(IO)(F)
# get *who* is the *owner* of the drive e:
explorer.exe e:\
# administrators

# %%
# what is GR,GE
# maybe i will search my notes
# GR = Generic Read probably
# GE = Generic Execute probably
# found 2 files about GR,GE

# i need an icacls command to protect the NTFS partition, from any modification,  by Everyone, Users, Authenticated Users, etc.

# what do security experts recommend?

# %%
icacls g:\
# Out:
# g:\ BUILTIN\Administrators:(F)
#     BUILTIN\Administrators:(OI)(CI)(IO)(F)
#     NT AUTHORITY\SYSTEM:(F)
#     NT AUTHORITY\SYSTEM:(OI)(CI)(IO)(F)
#     NT AUTHORITY\Authenticated Users:(M)
#     NT AUTHORITY\Authenticated Users:(OI)(CI)(IO)(M)
#     BUILTIN\Users:(RX)
#     BUILTIN\Users:(OI)(CI)(IO)(GR,GE)
#
# Successfully processed 1 files; Failed processing 0 files
