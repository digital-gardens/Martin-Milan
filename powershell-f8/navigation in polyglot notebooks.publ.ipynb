# %% [markdown]
# \t
# &emsp;
# $
#
#
# navigation in polyglot notebooks.publ.ipynb
#
# depends on mode
#
# cell
# or esc
#
# rclick
# or keyboard  to open the context menu
#
#
# f1
# polyglot
# notebook
